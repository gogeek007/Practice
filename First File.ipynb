# %%
import pandas as pd

# %%
x = pd.read_csv(r"C:\Users\Anup Saini\Desktop\Cars.csv")

# %%
x
# Out:
#                  Models  Mileage  Cyl   Disp   HP  Gear
# 0             Mazda RX4     21.0    6  160.0  110     4
# 1         Mazda RX4 Wag     21.0    6  160.0  110     4
# 2            Datsun 710     22.8    4  108.0   93     4
# 3        Hornet 4 Drive     21.4    6  258.0  110     3
# 4     Hornet Sportabout     18.7    8  360.0  175     3
# 5               Valiant     18.1    6  225.0  105     3
# 6            Duster 360     14.3    8  360.0  245     3
# 7             Merc 240D     24.4    4  146.7   62     4
# 8              Merc 230     22.8    4  140.8   95     4
# 9              Merc 280     19.2    6  167.6  123     4
# 10            Merc 280C     17.8    6  167.6  123     4
# 11           Merc 450SE     16.4    8  275.8  180     3
# 12           Merc 450SL     17.3    8  275.8  180     3
# 13          Merc 450SLC     15.2    8  275.8  180     3
# 14   Cadillac Fleetwood     10.4    8  472.0  205     3
# 15  Lincoln Continental     10.4    8  460.0  215     3
# ...

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Anup Saini'
